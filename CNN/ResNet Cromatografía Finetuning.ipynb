# %% [markdown]
# # **Importación de los datos desde repositorio Github**

# %%
import cv2
import os
import subprocess
import shutil

# Clonar el repositorio de GitHub
repo_url = 'https://github.com/skyteck8/Cromatography-Dataset.git'

subprocess.run(['git', 'clone', repo_url])
# Out:
# CompletedProcess(args=['git', 'clone', 'https://github.com/skyteck8/Cromatography-Dataset.git'], returncode=0)

# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
# from keras.applications import VGG19

# %%
# from keras.applications import VGG16

# %%
IMAGE_SIZE = (224, 224)

# %% [markdown]
# **The load_train_data function is designed to prepare training data for a classification task from a given folder path. It first initializes empty lists to store images (X) and their corresponding labels (y). It then extracts the class names by listing directories within the provided folder path. For each class, it iterates through the images, loads them using load_img, resizes them to a specified target size, converts them to arrays using img_to_array, and appends both the image arrays and their corresponding class labels to the X and y lists, respectively. Finally, it converts these lists into NumPy arrays and returns them. Overall, the function efficiently organizes and preprocesses the training data, making it ready for training a classification model.**

# %%
def load_train_data(folder_path):
    X = []
    y = []
    class_names = os.listdir(folder_path)
    print(class_names)

    for i, class_name in enumerate(class_names):
        class_path = os.path.join(folder_path, class_name)
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)
            image = load_img(image_path, target_size=IMAGE_SIZE)
            image = img_to_array(image)
            X.append(image)
            y.append(i)
    X = np.array(X)
    y = np.array(y)
    return X, y

# %% [markdown]
# **The load_test_data function is responsible for loading and preprocessing test data for a classification task from a specified folder path.**

# %%
def load_test_data(folder_path):
    X = []
    filenames = []
    for image_name in os.listdir(folder_path):
        if image_name.endswith('.jpg'):
            image_path = os.path.join(folder_path, image_name)
            image = load_img(image_path, target_size=IMAGE_SIZE)
            image = img_to_array(image)
            X.append(image)
            filenames.append(image_name)
    X = np.array(X)
    return X, filenames

# %%
train_folder = '/content/Cromatography-Dataset/train3Classes'
# test_folder = '/content/FlowerDataset/test'
X_train, y_train = load_train_data(train_folder)
# X_test, test_filenames = load_test_data(test_folder)
# Out:
# ['0', '1', '2']

# %% [markdown]
# **Converting the data type of the arrays X_train and X_test to float32 and then scales the pixel values to the range [0, 1] by dividing each pixel value by 255.0. This normalization process improves the convergence of the neural network during training by ensuring that the input data is within a consistent range**

# %%
X_train = X_train.astype('float32') / 255.0
# X_test = X_test.astype('float32') / 255.0

# %% [markdown]
# **Split training data into train and validation sets**

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# vgg16_base = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
# NUM_CLASSES = 5
# model = Sequential()
# model.add(vgg16_base)
# model.add(Flatten())
# model.add(Dense(256, activation='relu'))
# model.add(Dense(NUM_CLASSES, activation='softmax'))

# %%
# NUM_CLASSES = 5
# # Definir el tamaño de entrada esperado por VGG16
# input_tensor = Input(shape=(224, 224, 3))

# # Crear la base de VGG16 con los pesos preentrenados, sin incluir las capas superiores
# vgg16_base = VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)

# # Crear el modelo secuencial
# model = Sequential()
# model.add(vgg16_base)  # Añade la base VGG16
# model.add(Flatten())   # Aplanar los resultados de las capas convolucionales
# model.add(Dense(256, activation='relu'))  # Añadir una capa densa
# model.add(Dense(NUM_CLASSES, activation='softmax'))  # Capa de salida softmax para clasificación

# Asegúrate de que el modelo se compila
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# **Ensuring that the pre-trained weights of the VGG16 model are not modified during training.**

# %%
# vgg16_base.trainable = False

# %%
# input_tensor = Input(shape=(224, 224, 3))

# # Crear la base de VGG16 con los pesos preentrenados, sin incluir las capas superiores
# vgg16_base = VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)

# # Crear el modelo secuencial
# model = Sequential()
# model.add(vgg16_base)  # Añade la base VGG16
# model.add(Flatten())   # Aplanar los resultados de las capas convolucionales
# model.add(Dense(256, activation='relu'))  # Añadir una capa densa
# model.add(Dense(3, activation='softmax'))  # Capa de salida softmax para clasificación
# model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.applications import ResNet50
from keras.models import Sequential
from keras.layers import Input, Flatten, Dense
from keras.optimizers import Adam

# Crear la base de ResNet50 con los pesos preentrenados, sin incluir las capas superiores
input_tensor = Input(shape=(224, 224, 3))
resnet50_base = ResNet50(include_top=False, weights='imagenet', input_tensor=input_tensor)

# Congelar las capas de ResNet50
resnet50_base.trainable = False

# Crear el modelo secuencial
model = Sequential()
model.add(resnet50_base)  # Añade la base ResNet50
model.add(Flatten())   # Aplanar los resultados de las capas convolucionales
model.add(Dense(256, activation='relu'))  # Añadir una capa densa
model.add(Dense(3, activation='softmax'))  # Capa de salida softmax para clasificación

# Compilar el modelo
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 6s 0us/step

# %%
BATCH_SIZE = 128
EPOCHS = 5
NUM_CLASSES = 5

# %%
model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=100, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 453ms/step - loss: 0.6758 - accuracy: 0.7375 - val_loss: 0.6661 - val_accuracy: 0.8000
# Epoch 2/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6738 - accuracy: 0.7375 - val_loss: 0.6650 - val_accuracy: 0.8000
# Epoch 3/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.6715 - accuracy: 0.7375 - val_loss: 0.6643 - val_accuracy: 0.8000
# Epoch 4/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6694 - accuracy: 0.7375 - val_loss: 0.6634 - val_accuracy: 0.8000
# Epoch 5/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6674 - accuracy: 0.7375 - val_loss: 0.6616 - val_accuracy: 0.8000
# Epoch 6/100
# 1/1 [==============================] - 0s 314ms/step - loss: 0.6652 - accuracy: 0.7375 - val_loss: 0.6597 - val_accuracy: 0.8000
# Epoch 7/100
# 1/1 [==============================] - 0s 315ms/step - loss: 0.6631 - accuracy: 0.7375 - val_loss: 0.6582 - val_accuracy: 0.8000
# Epoch 8/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.6611 - accuracy: 0.7375 - val_loss: 0.6571 - val_accuracy: 0.8000
# Epoch 9/100
# 1/1 [==============================] - 0s 315ms/step - loss: 0.6589 - accuracy: 0.7375 - val_loss: 0.6562 - val_accuracy: 0.8000
# Epoch 10/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6569 - accuracy: 0.7375 - val_loss: 0.6552 - val_accuracy: 0.8000
# Epoch 11/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6549 - accuracy: 0.7375 - val_loss: 0.6537 - val_accuracy: 0.8000
# Epoch 12/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6529 - accuracy: 0.7375 - val_loss: 0.6521 - val_accuracy: 0.8000
# Epoch 13/100
# 1/1 [==============================] - 0s 334ms/step - loss: 0.6509 - accuracy: 0.7375 - val_loss: 0.6507 - val_accuracy: 0.8000
# Epoch 14/100
# 1/1 [==============================] - 0s 340ms/step - loss: 0.6489 - accuracy: 0.7375 - val_loss: 0.6497 - val_accuracy: 0.8000
# Epoch 15/100
# 1/1 [==============================] - 0s 342ms/step - loss: 0.6469 - accuracy: 0.7375 - val_loss: 0.6490 - val_accuracy: 0.8000
# Epoch 16/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.6449 - accuracy: 0.7375 - val_loss: 0.6482 - val_accuracy: 0.8000
# Epoch 17/100
# 1/1 [==============================] - 0s 340ms/step - loss: 0.6430 - accuracy: 0.7375 - val_loss: 0.6469 - val_accuracy: 0.8000
# Epoch 18/100
# 1/1 [==============================] - 0s 353ms/step - loss: 0.6410 - accuracy: 0.7375 - val_loss: 0.6455 - val_accuracy: 0.8000
# Epoch 19/100
# 1/1 [==============================] - 0s 343ms/step - loss: 0.6391 - accuracy: 0.7375 - val_loss: 0.6444 - val_accuracy: 0.8000
# Epoch 20/100
# 1/1 [==============================] - 0s 317ms/step - loss: 0.6372 - accuracy: 0.7375 - val_loss: 0.6435 - val_accuracy: 0.8000
# Epoch 21/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.6353 - accuracy: 0.7375 - val_loss: 0.6427 - val_accuracy: 0.8000
# Epoch 22/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6334 - accuracy: 0.7375 - val_loss: 0.6417 - val_accuracy: 0.8000
# Epoch 23/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6316 - accuracy: 0.7375 - val_loss: 0.6404 - val_accuracy: 0.8000
# Epoch 24/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.6297 - accuracy: 0.7375 - val_loss: 0.6392 - val_accuracy: 0.8000
# Epoch 25/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.6278 - accuracy: 0.7375 - val_loss: 0.6381 - val_accuracy: 0.8000
# Epoch 26/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.6260 - accuracy: 0.7375 - val_loss: 0.6372 - val_accuracy: 0.8000
# Epoch 27/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.6241 - accuracy: 0.7375 - val_loss: 0.6364 - val_accuracy: 0.8000
# Epoch 28/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.6223 - accuracy: 0.7375 - val_loss: 0.6354 - val_accuracy: 0.8000
# Epoch 29/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.6205 - accuracy: 0.7375 - val_loss: 0.6343 - val_accuracy: 0.8000
# Epoch 30/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.6187 - accuracy: 0.7375 - val_loss: 0.6333 - val_accuracy: 0.8000
# Epoch 31/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.6169 - accuracy: 0.7375 - val_loss: 0.6324 - val_accuracy: 0.8000
# Epoch 32/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.6151 - accuracy: 0.7375 - val_loss: 0.6316 - val_accuracy: 0.8000
# Epoch 33/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.6133 - accuracy: 0.7375 - val_loss: 0.6307 - val_accuracy: 0.8000
# Epoch 34/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.6116 - accuracy: 0.7375 - val_loss: 0.6297 - val_accuracy: 0.8000
# Epoch 35/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6098 - accuracy: 0.7375 - val_loss: 0.6288 - val_accuracy: 0.8000
# Epoch 36/100
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6081 - accuracy: 0.7375 - val_loss: 0.6279 - val_accuracy: 0.8000
# Epoch 37/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.6063 - accuracy: 0.7375 - val_loss: 0.6271 - val_accuracy: 0.8000
# Epoch 38/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.6046 - accuracy: 0.7375 - val_loss: 0.6262 - val_accuracy: 0.8000
# Epoch 39/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.6029 - accuracy: 0.7375 - val_loss: 0.6254 - val_accuracy: 0.8000
# Epoch 40/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.6011 - accuracy: 0.7375 - val_loss: 0.6245 - val_accuracy: 0.8000
# Epoch 41/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.5994 - accuracy: 0.7375 - val_loss: 0.6237 - val_accuracy: 0.8000
# Epoch 42/100
# 1/1 [==============================] - 0s 313ms/step - loss: 0.5977 - accuracy: 0.7375 - val_loss: 0.6230 - val_accuracy: 0.8000
# Epoch 43/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.5960 - accuracy: 0.7375 - val_loss: 0.6222 - val_accuracy: 0.8000
# Epoch 44/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.5943 - accuracy: 0.7375 - val_loss: 0.6213 - val_accuracy: 0.8000
# Epoch 45/100
# 1/1 [==============================] - 0s 308ms/step - loss: 0.5926 - accuracy: 0.7375 - val_loss: 0.6205 - val_accuracy: 0.8000
# Epoch 46/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.5910 - accuracy: 0.7375 - val_loss: 0.6197 - val_accuracy: 0.8000
# Epoch 47/100
# 1/1 [==============================] - 0s 305ms/step - loss: 0.5893 - accuracy: 0.7500 - val_loss: 0.6191 - val_accuracy: 0.8000
# Epoch 48/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.5876 - accuracy: 0.7500 - val_loss: 0.6184 - val_accuracy: 0.8000
# Epoch 49/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.5860 - accuracy: 0.7500 - val_loss: 0.6176 - val_accuracy: 0.8000
# Epoch 50/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.5843 - accuracy: 0.7500 - val_loss: 0.6168 - val_accuracy: 0.8000
# Epoch 51/100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.5827 - accuracy: 0.7625 - val_loss: 0.6161 - val_accuracy: 0.8000
# Epoch 52/100
# 1/1 [==============================] - 0s 321ms/step - loss: 0.5811 - accuracy: 0.7625 - val_loss: 0.6155 - val_accuracy: 0.8000
# Epoch 53/100
# 1/1 [==============================] - 0s 407ms/step - loss: 0.5794 - accuracy: 0.7625 - val_loss: 0.6149 - val_accuracy: 0.8000
# Epoch 54/100
# 1/1 [==============================] - 0s 356ms/step - loss: 0.5778 - accuracy: 0.7625 - val_loss: 0.6143 - val_accuracy: 0.8000
# Epoch 55/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0
100
# 1/1 [==============================] - 0s 312ms/step - loss: 0.5317 - accuracy: 0.8375 - val_loss: 0.5984 - val_accuracy: 0.8500
# Epoch 85/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.5303 - accuracy: 0.8375 - val_loss: 0.5981 - val_accuracy: 0.8500
# Epoch 86/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.5288 - accuracy: 0.8375 - val_loss: 0.5978 - val_accuracy: 0.8500
# Epoch 87/100
# 1/1 [==============================] - 0s 311ms/step - loss: 0.5274 - accuracy: 0.8375 - val_loss: 0.5974 - val_accuracy: 0.8500
# Epoch 88/100
# 1/1 [==============================] - 0s 306ms/step - loss: 0.5260 - accuracy: 0.8375 - val_loss: 0.5969 - val_accuracy: 0.8500
# Epoch 89/100
# 1/1 [==============================] - 0s 318ms/step - loss: 0.5246 - accuracy: 0.8375 - val_loss: 0.5964 - val_accuracy: 0.8000
# Epoch 90/100
# 1/1 [==============================] - 0s 325ms/step - loss: 0.5232 - accuracy: 0.8250 - val_loss: 0.5960 - val_accuracy: 0.8000
# Epoch 91/100
# 1/1 [==============================] - 0s 335ms/step - loss: 0.5218 - accuracy: 0.8375 - val_loss: 0.5957 - val_accuracy: 0.8000
# Epoch 92/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.5204 - accuracy: 0.8375 - val_loss: 0.5953 - val_accuracy: 0.8000
# Epoch 93/100
# 1/1 [==============================] - 0s 324ms/step - loss: 0.5190 - accuracy: 0.8375 - val_loss: 0.5949 - val_accuracy: 0.8000
# Epoch 94/100
# 1/1 [==============================] - 0s 354ms/step - loss: 0.5176 - accuracy: 0.8375 - val_loss: 0.5944 - val_accuracy: 0.8000
# Epoch 95/100
# 1/1 [==============================] - 0s 337ms/step - loss: 0.5162 - accuracy: 0.8375 - val_loss: 0.5940 - val_accuracy: 0.8000
# Epoch 96/100
# 1/1 [==============================] - 0s 336ms/step - loss: 0.5148 - accuracy: 0.8375 - val_loss: 0.5936 - val_accuracy: 0.8000
# Epoch 97/100
# 1/1 [==============================] - 0s 429ms/step - loss: 0.5135 - accuracy: 0.8375 - val_loss: 0.5932 - val_accuracy: 0.8000
# Epoch 98/100
# 1/1 [==============================] - 0s 310ms/step - loss: 0.5121 - accuracy: 0.8375 - val_loss: 0.5928 - val_accuracy: 0.8000
# Epoch 99/100
# 1/1 [==============================] - 0s 309ms/step - loss: 0.5108 - accuracy: 0.8375 - val_loss: 0.5925 - val_accuracy: 0.8000
# Epoch 100/100
# 1/1 [==============================] - 0s 307ms/step - loss: 0.5094 - accuracy: 0.8375 - val_loss: 0.5921 - val_accuracy: 0.8000

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 49278851 (187.98 MB)
# Trainable params: 25691139 (98.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
model.evaluate(X_val,y_val)
# Out:
# 1/1 [==============================] - 0s 116ms/step - loss: 0.5921 - accuracy: 0.8000
# [0.5920625329017639, 0.800000011920929]

# %%
import tensorflow as tf
def preprocess_image(image):
    # Convertimos la imagen a un tensor si no lo es
    if not isinstance(image, tf.Tensor):
        image = tf.convert_to_tensor(image, dtype=tf.float32)

    # Redimensionamos la imagen al tamaño esperado por el modelo (224x224)
    image = tf.image.resize(image, (224, 224))

    # Normalizamos los valores de los píxeles a [0, 1]
    image = image / 255.0

    # Añadimos una dimensión para que sea compatible con el modelo (batch size)
    image = tf.expand_dims(image, axis=0)

    return image

# %%
print(model.predict(preprocess_image(X_train[20])))
# Out:
# 1/1 [==============================] - 2s 2s/step
# [[0.7892381  0.18387188 0.02689   ]]

# %%
import matplotlib.pyplot as plt

def display_image(image):
    # Si la imagen es un tensor, la convertimos a un numpy array
    if isinstance(image, tf.Tensor):
        image = image.numpy()

    # Si la imagen tiene una dimensión extra (batch size), la removemos
    if image.shape[0] == 1:
        image = image[0]

    # Mostramos la imagen
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
display_image(X_train[72])

# %%
model.save('ReconocimientoCromatografia.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
for i in range(len(X_train)):
  display_image(X_train[i])
  print(model.predict(preprocess_image(X_train[i])))

# %%
model.save('ReconocimientoCromatografia.keras')
